# %%
def mask(img):
  hsv_img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
  blue_low = np.array([100 , 20, 20])
  blue_high = np.array([255, 100, 100])
  curr_mask = cv2.inRange(hsv_img, blue_low, blue_high)
  hsv_img[curr_mask > 0] = ([100 , 20, 20])
  RGB_again = cv2.cvtColor(hsv_img, cv2.COLOR_HSV2RGB)
  gray = cv2.cvtColor(RGB_again, cv2.COLOR_RGB2GRAY)
  ret, threshold = cv2.threshold(gray, 130, 255, cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)
  return(threshold)

def seg(img):
  yield (cv2.bitwise_or(img, img, mask = mask(img)))

seg_list = []
for i in x:
  q = list(seg(i))
  seg_list.append(q[0])
